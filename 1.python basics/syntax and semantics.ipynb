# %%
##Basic syntax rules in python
## Case sensitivity: Python is case sensitive when dealing with identifiers. 
name="Krish"
Name="Naik"
print(name)
print(Name)
# Out:
# Krish
# Naik

# %%
## Indentation 
## Python uses indentation to define blocks of code. Cosnsistent use of spaces(commanly 4) or a tab is required.
age=18
if age>30:
    print(age)
else:
    print("NO")
# Out:
# NO

# %%
## This is sigle line comment
print("Hello World")
# Out:
# Hello World

# %%
## Line continuation
total=1+2+3+4+5+6+\
7+8
print(total)
# Out:
# 36

# %%
## MUltiple statements on a sigle line
x=5;y=3;z=x+y
print(z)
# Out:
# 8

# %%
## Understand Semantics in Python
# variable assignment
age=32 ##age is a number
name= "neha" ##name is a string

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
## Type Inference
variable=10
print(type(variable))
variable="neha"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
## Indentation Error
age=32
if age>30:
print(age)
# Out:
#   Cell In[19], line 3
#     print(age)
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
## NameError
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 ## NameError
# ----> 2 a=b
#
# NameError: name 'b' is not defined

# %%
## Code example for indentation
if True:
    print("Correct Indentation")
    if False:
        prrint("This not print")
    print("This will print")
print("Outside the if block")
# Out:
# Correct Indentation
# This will print
# Outside the if block
